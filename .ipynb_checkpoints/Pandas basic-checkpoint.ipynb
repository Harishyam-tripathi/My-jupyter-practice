# %% [markdown]
# # Python with PANDAS

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#1.Create Dataframe
df = pd.DataFrame([11,22,33], columns = ['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    'Name': ['Mahesh','Ramesh','Vishal','Suresh'],
    'Age': [16,18,20,22],
    'Salary': [2000, 5000,3000,4000],
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary
# 0  Mahesh   16    2000
# 1  Ramesh   18    5000
# 2  Vishal   20    3000
# 3  Suresh   22    4000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#2. Basic Dataframe Understanding

# %%
df.head(2)
# Out:
#      Name  Age  Salary
# 0  Mahesh   16    2000
# 1  Ramesh   18    5000

# %%
df.tail(2)
# Out:
#      Name  Age  Salary
# 2  Vishal   20    3000
# 3  Suresh   22    4000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary':'Monthly_Salary'})
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            2000
# 1  Ramesh   18            5000
# 2  Vishal   20            3000
# 3  Suresh   22            4000

# %%
df
# Out:
#      Name  Age  Salary
# 0  Mahesh   16    2000
# 1  Ramesh   18    5000
# 2  Vishal   20    3000
# 3  Suresh   22    4000

# %%
df.rename(columns={'Salary':'Monthly_Salary'}, inplace = True)

# %%
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            2000
# 1  Ramesh   18            5000
# 2  Vishal   20            3000
# 3  Suresh   22            4000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   19.000000     3500.000000
# std     2.581989     1290.994449
# min    16.000000     2000.000000
# 25%    17.500000     2750.000000
# 50%    19.000000     3500.000000
# 75%    20.500000     4250.000000
# max    22.000000     5000.000000

# %%
#3. Save and Load data from csv

# %%
df.to_csv('Test_data.csv', index=False) # Export dataframe

# %%
Demo= pd.read_csv('Test_data.csv') # Import dataframe
Demo
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            8000
# 1  Ramesh   18            5000
# 2  Vishal   20            3000
# 3  Suresh   22            4000

# %%
Demo
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            8000
# 1  Ramesh   18            5000
# 2  Vishal   20            3000
# 3  Suresh   22            4000

# %%
Demo.head(2)
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            8000
# 1  Ramesh   18            5000

# %%
Demo.tail()
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            8000
# 1  Ramesh   18            5000
# 2  Vishal   20            3000
# 3  Suresh   22            4000

# %%
#4. Rows & Column - Selection 
Demo[['Name']] # single column
# Out:
#      Name
# 0  Mahesh
# 1  Ramesh
# 2  Vishal
# 3  Suresh

# %%
 Demo[['Name','Monthly_Salary']]
# Out:
#      Name  Monthly_Salary
# 0  Mahesh            8000
# 1  Ramesh            5000
# 2  Vishal            3000
# 3  Suresh            4000

# %%
# select rows
# Loc - based index
Demo.loc[Demo.Name=='Mahesh']
# Out:
#      Name  Age  Monthly_Salary
# 0  Mahesh   16            8000

# %%
Demo.loc[(df.Name=='Mahesh') & (df.Monthly_Salary>=5000)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Monthly_Salary]
# Index: []

# %%
Demo.loc[Demo.Name=='Ramesh']
# Out:
#      Name  Age  Monthly_Salary
# 1  Ramesh   18            5000
